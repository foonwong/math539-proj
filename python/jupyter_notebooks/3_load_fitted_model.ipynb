# %%
# Change directory to VSCode workspace root so that relative path loads work correctly. Turn this addition off with the DataScience.changeDirOnImportExport setting
import os
try:
	os.chdir(os.path.join(os.getcwd(), '../..'))
	print(os.getcwd())
except:
	pass

# %% [markdown]
# # Example on how to use fitted objects

# %%
from sklearn.externals import joblib
from sklearn.metrics import mean_absolute_error, mean_squared_error
from math import sqrt 
import os
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading fitted models

# %%
alljoblibs = os.listdir('models')
print(alljoblibs)
# Out:
# ['lgb_tuned_datacap_lower_quantile_20190507_02_35.joblib', 'lgb_tuned_timecap_upper_quantile_20190507_10_22.joblib', 'lgb_tuned_datacap_median_quantile_20190507_02_35.joblib', 'lgb_tuned_datacap_upper_quantile_20190507_02_35.joblib', 'lgb_tuned_fulldata_lower_quantile_20190507_07_25.joblib', 'lgb_tuned_timecap_lower_quantile_20190507_10_22.joblib', 'lgb_tuned_fulldata_upper_quantile_20190507_07_25.joblib', 'lgb_tuned_timecap_median_quantile_20190507_10_22.joblib', 'lgb_tuned_fulldata_median_quantile_20190507_07_25.joblib', 'old']

# %%
subset = {'datacap':{}, 'timecap':{},'fulldata':{}}

print('loading files double loop:') 
for sub in subset:
    joblibs = [file for file in alljoblibs if sub in file]

    for quantile in ['upper', 'median', 'lower']:
        path = [f'models/{x}' for x in joblibs if quantile in x][0]
        loaded = joblib.load(path)
        subset[sub].update({quantile: loaded})

        print(f'Loaded {sub}-{quantile} --- RMSE: {loaded["RMSE"]:.4f}')

print(subset.keys())
print(subset['datacap'].keys())
# Out:
# loading files double loop:
# Loaded datacap-upper --- RMSE: 0.3099
# Loaded datacap-median --- RMSE: 0.1525
# Loaded datacap-lower --- RMSE: 0.2250
# Loaded timecap-upper --- RMSE: 0.5251
# Loaded timecap-median --- RMSE: 0.4461
# Loaded timecap-lower --- RMSE: 0.5040
# Loaded fulldata-upper --- RMSE: 0.5261
# Loaded fulldata-median --- RMSE: 0.3807
# Loaded fulldata-lower --- RMSE: 0.4690
# dict_keys(['datacap', 'timecap', 'fulldata'])
# dict_keys(['upper', 'median', 'lower'])

# %% [markdown]
# ## Let's say these are the rows that we want to apply model

# %%
dummy_data = subset['datacap']['median']['X_sample']
dummy_data = dummy_data.head(10)

dummy_data.index = np.arange(0, dummy_data.shape[0])  # resetting index from 0:nrows
dummy_data
# Out:
#    airline  flight_duration_hrs  orig_country  seat_count  night_flight  \
# 0        5            10.968750            32       310.0         False
# 1        6             4.050781            85       288.0         False
# 2       12             8.000000            88       236.0         False
# 3        1             7.871094            15       243.0          True
# 4       12             7.320312            88       236.0         False
# 5        1            10.781250            60       243.0          True
# 6       12             5.800781            88       236.0         False
# 7       12            10.203125            16       236.0         False
# 8       13             8.320312            91       321.0         False
# 9        3            11.828125            48       256.0         False
#
#    flight_type  price_usd   ife  e_xtv  e_xphone  one_media  dest_country  \
# 0            1  20.765625  True  False      True       True            86
# 1            1  34.781250  True  False     False      False            43
# 2            1  39.375000  True  False      True      False            91
# 3            1   1.950195  True   True     False       True            55
# 4            1  19.187500  True  False      True      False            48
# 5            1   1.950195  True   True     False       True            59
# 6            1   9.093750  True  False      True      False            89
# 7            1  39.375000  True  False      True      False            83
# 8            1   8.992188  True   True     False      False             2
# 9            1   6.000000  True   True      True      False            44
#
#    economy_pct  bus_pass_percent  luxury  datacap_mb
# 0         93.0         20.953125   False        50.0
# 1         93.0         20.953125   False       200.0
# 2         78.0         33.687500   False       120.0
# 3         87.0         26.046875   False         5.0
# 4         78.0         33.687500   False        50.0
# 5         87.0         26.046875   False         5.0
# 6         78.0         33.687500   False        20.0
# 7         78.0         33.687500   False       120.0
# 8         90.0         23.500000   False        20.0
# 9         86.0         26.906250   False        50.0

# %%
predictions = {}
for quantile, fit_objs in subset['datacap'].items():
    model = fit_objs['model']

    predictions.update({f'y_predicted_{quantile}': model.predict(dummy_data)})

predictions = pd.DataFrame(predictions)
predictions
# Out:
#    y_predicted_upper  y_predicted_median  y_predicted_lower
# 0           0.390835            0.159761           0.076028
# 1           0.321795            0.131638           0.104750
# 2           1.253938            0.451237           0.167290
# 3           0.035497            0.013340           0.008011
# 4           0.746985            0.335702           0.083869
# 5           0.078924            0.025644           0.007746
# 6           0.214614            0.081105           0.040561
# 7           0.722128            0.178592           0.166160
# 8           0.209045            0.056623           0.033812
# 9           0.356372            0.112069           0.019186

# %%
# Combining model predictions and data
predicted_df = pd.concat([predictions, dummy_data], axis=1)
predicted_df
# Out:
#    y_predicted_upper  y_predicted_median  y_predicted_lower  airline  \
# 0           0.390835            0.159761           0.076028        5
# 1           0.321795            0.131638           0.104750        6
# 2           1.253938            0.451237           0.167290       12
# 3           0.035497            0.013340           0.008011        1
# 4           0.746985            0.335702           0.083869       12
# 5           0.078924            0.025644           0.007746        1
# 6           0.214614            0.081105           0.040561       12
# 7           0.722128            0.178592           0.166160       12
# 8           0.209045            0.056623           0.033812       13
# 9           0.356372            0.112069           0.019186        3
#
#    flight_duration_hrs  orig_country  seat_count  night_flight  flight_type  \
# 0            10.968750            32       310.0         False            1
# 1             4.050781            85       288.0         False            1
# 2             8.000000            88       236.0         False            1
# 3             7.871094            15       243.0          True            1
# 4             7.320312            88       236.0         False            1
# 5            10.781250            60       243.0          True            1
# 6             5.800781            88       236.0         False            1
# 7            10.203125            16       236.0         False            1
# 8             8.320312            91       321.0         False            1
# 9            11.828125            48       256.0         False            1
#
#    price_usd   ife  e_xtv  e_xphone  one_media  dest_country  economy_pct  \
# 0  20.765625  True  False      True       True            86         93.0
# 1  34.781250  True  False     False      False            43         93.0
# 2  39.375000  True  False      True      False            91         78.0
# 3   1.950195  True   True     False       True            55         87.0
# 4  19.187500  True  False      True      False            48         78.0
# 5   1.950195  True   True     False       True            59         87.0
# 6   9.093750  True  False      True      False            89         78.0
# 7  39.375000  True  False      True      False            83         78.0
# 8   8.992188  True   True     False      False             2         90.0
# 9   6.000000  True   True      True      False            44         86.0
#
#    bus_pass_percent  luxury  datacap_mb
# 0         20.953125   False        50.0
# 1         20.953125   False       200.0
# 2         33.687500   False       120.0
# 3         26.046875   False         5.0
# 4         33.687500   False        50.0
# 5         26.046875   False         5.0
# 6         33.687500   False        20.0
# 7         33.687500   False       120.0
# 8         23.500000   False        20.0
# 9         26.906250   False        50.0

# %% [markdown]
# ## Inverse label transformation
#  The dummy data I used above has already been label transformed
#  because they are the actual traning data.
#  To return the actual categories, we need to use the label encoder saved

# %%
lab_encoder = subset['datacap']['median']['label_encoders']

for col, le in lab_encoder.items():
    inv_transformer = le.inverse_transform
    predicted_df[col] = predicted_df[col].transform(inv_transformer)

predicted_df
# Out:
#    y_predicted_upper  y_predicted_median  y_predicted_lower airline  \
# 0           0.390835            0.159761           0.076028     EWG
# 1           0.321795            0.131638           0.104750     IBE
# 2           1.253938            0.451237           0.167290     SWR
# 3           0.035497            0.013340           0.008011     AMX
# 4           0.746985            0.335702           0.083869     SWR
# 5           0.078924            0.025644           0.007746     AMX
# 6           0.214614            0.081105           0.040561     SWR
# 7           0.722128            0.178592           0.166160     SWR
# 8           0.209045            0.056623           0.033812     THA
# 9           0.356372            0.112069           0.019186     AZA
#
#    flight_duration_hrs orig_country  seat_count  night_flight    flight_type  \
# 0            10.968750      Germany       310.0         False  International
# 1             4.050781        Spain       288.0         False  International
# 2             8.000000  Switzerland       236.0         False  International
# 3             7.871094        Chile       243.0          True  International
# 4             7.320312  Switzerland       236.0         False  International
# 5            10.781250       Mexico       243.0          True  International
# 6             5.800781  Switzerland       236.0         False  International
# 7            10.203125        China       236.0         False  International
# 8             8.320312     Thailand       321.0         False  International
# 9            11.828125        Japan       256.0         False  International
#
#    price_usd   ife  e_xtv  e_xphone  one_media          dest_country  \
# 0  20.765625  True  False      True       True              Thailand
# 1  34.781250  True  False     False      False                Israel
# 2  39.375000  True  False      True      False         United States
# 3   1.950195  True   True     False       True                Mexico
# 4  19.187500  True  False      True      False                 Kenya
# 5   1.950195  True   True     False       True           Netherlands
# 6   9.093750  True  False      True      False  United Arab Emirates
# 7  39.375000  True  False      True      False           Switzerland
# 8   8.992188  True   True     False      False             Australia
# 9   6.000000  True   True      True      False                 Italy
#
#    economy_pct  bus_pass_percent  luxury  datacap_mb
# 0         93.0         20.953125   False        50.0
# 1         93.0         20.953125   False       200.0
# 2         78.0         33.687500   False       120.0
# 3         87.0         26.046875   False         5.0
# 4         78.0         33.687500   False        50.0
# 5         87.0         26.046875   False         5.0
# 6         78.0         33.687500   False        20.0
# 7         78.0         33.687500   False       120.0
# 8         90.0         23.500000   False        20.0
# 9         86.0         26.906250   False        50.0

# %% [markdown]
# ## label transformation
#  I'll need to write functions for this, but for now, the following should work

# %%
# new_df     # insert your own here
# new_df_encoded = new_df.copy()   # otherwise dataframes are modified by reference
# lab_encoder = subset['datacap']['median']['label_encoders']
# 
# for col, le in lab_encoder.items():
    # transformer = le.inverse_transform
    # new_df_encoded[col] = new_df_encoded[col].transform(transformer)
